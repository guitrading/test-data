# %%
import pandas as pd

# %%
df = pd.read_csv('data_feed.csv')
df
# Out:
#                           Date         A       ABC       ADI       ADM  \
# 0    2022-01-20 00:00:00-05:00 -0.006765  0.003701 -0.027168 -0.029718
# 1    2022-01-21 00:00:00-05:00 -0.014124 -0.010235  0.005611  0.000726
# 2    2022-01-24 00:00:00-05:00  0.004436  0.000228  0.012036 -0.005077
# 3    2022-01-25 00:00:00-05:00 -0.025702 -0.003725 -0.035121 -0.003207
# 4    2022-01-26 00:00:00-05:00 -0.007877 -0.003891  0.025679  0.057043
# ..                         ...       ...       ...       ...       ...
# 171  2022-09-26 00:00:00-04:00 -0.009475 -0.006195 -0.007751 -0.001715
# 172  2022-09-27 00:00:00-04:00 -0.005723 -0.006674  0.007030 -0.008465
# 173  2022-09-28 00:00:00-04:00  0.017351  0.021929  0.019533  0.025860
# 174  2022-09-29 00:00:00-04:00 -0.007921 -0.016906 -0.017914 -0.027741
# 175  2022-09-30 00:00:00-04:00 -0.009695 -0.005438 -0.018663 -0.001985
#
#           ADP      ADSK       AEE       AEP       AES  ...       WRB  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], utc=True)
df.set_index('Date', inplace=True)
df
# Out:
#                                   A       ABC       ADI       ADM       ADP  \
# Date
# 2022-01-20 05:00:00+00:00 -0.006765  0.003701 -0.027168 -0.029718 -0.020104
# 2022-01-21 05:00:00+00:00 -0.014124 -0.010235  0.005611  0.000726 -0.014434
# 2022-01-24 05:00:00+00:00  0.004436  0.000228  0.012036 -0.005077  0.005112
# 2022-01-25 05:00:00+00:00 -0.025702 -0.003725 -0.035121 -0.003207 -0.006232
# 2022-01-26 05:00:00+00:00 -0.007877 -0.003891  0.025679  0.057043 -0.089543
# ...                             ...       ...       ...       ...       ...
# 2022-09-26 04:00:00+00:00 -0.009475 -0.006195 -0.007751 -0.001715 -0.007122
# 2022-09-27 04:00:00+00:00 -0.005723 -0.006674  0.007030 -0.008465 -0.004461
# 2022-09-28 04:00:00+00:00  0.017351  0.021929  0.019533  0.025860  0.019023
# 2022-09-29 04:00:00+00:00 -0.007921 -0.016906 -0.017914 -0.027741 -0.018107
# 2022-09-30 04:00:00+00:00 -0.009695 -0.005438 -0.018663 -0.001985 -0.006850
#
# ...

# %%
df.index = df.index.date

# %%
df
# Out:
#                    A       ABC       ADI       ADM       ADP      ADSK  \
# 2022-01-20 -0.006765  0.003701 -0.027168 -0.029718 -0.020104 -0.007627
# 2022-01-21 -0.014124 -0.010235  0.005611  0.000726 -0.014434 -0.052375
# 2022-01-24  0.004436  0.000228  0.012036 -0.005077  0.005112  0.025754
# 2022-01-25 -0.025702 -0.003725 -0.035121 -0.003207 -0.006232 -0.047157
# 2022-01-26 -0.007877 -0.003891  0.025679  0.057043 -0.089543 -0.002139
# ...              ...       ...       ...       ...       ...       ...
# 2022-09-26 -0.009475 -0.006195 -0.007751 -0.001715 -0.007122 -0.003088
# 2022-09-27 -0.005723 -0.006674  0.007030 -0.008465 -0.004461  0.021577
# 2022-09-28  0.017351  0.021929  0.019533  0.025860  0.019023  0.016067
# 2022-09-29 -0.007921 -0.016906 -0.017914 -0.027741 -0.018107 -0.007959
# 2022-09-30 -0.009695 -0.005438 -0.018663 -0.001985 -0.006850 -0.014040
#
#                  AEE       AEP       AES       AFL  ...       WRB       WST  \
# ...

# %%
df.to_csv('data_feed_updated.csv')
